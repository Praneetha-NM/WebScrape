# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneetha-NM/WebScrape/blob/main/WebScrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import random

# %%
# Define Headers and Base URL
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 13_5) AppleWebKit/537.36 (KHTML, like Gecko) Version/17.5 Safari/537.36',
    'Accept-Language': 'en-US, en;q=0.5'
}
BASE_URL = "https://www.amazon.com"

# %%
# Extract Links
def get_product_links(url):
    webpage = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    links = soup.find_all("a", attrs={'class': 'a-link-normal s-no-outline'})
    return [link.get('href') for link in links if link.get('href')]

# %%
def get_product_details(link):
    time.sleep(random.uniform(2, 5))  # Avoid bot detection
    if not link.startswith('http'):
        link = BASE_URL + link
    response = requests.get(link, headers=HEADERS)
    soup = BeautifulSoup(response.content, "html.parser")

    return {
        "title": get_title(soup),
        "price": get_price(soup),
        "rating": get_rating(soup),
        "reviews": get_review_count(soup),
        "availability": get_availability(soup),
        "product_details": get_product_description(soup),
        "image_url": get_image_url(soup),
        "brand": get_brand(soup)
    }

# %%
# Function Definitions
def get_title(soup):
    try:
        return soup.find("span", attrs={"id": "productTitle"}).text.strip()
    except AttributeError:
        return "No Title Found"

# %%
def get_price(soup):
    try:
        # Attempt to find prices under different IDs or classes
        price = soup.find("span", attrs={"id": "priceblock_ourprice"})
        if not price:
            price = soup.find("span", attrs={"id": "priceblock_dealprice"})
        if not price:
            price = soup.find("span", attrs={"class": "a-price-whole"})
        if price:
            return price.text.strip()
        else:
            return "Price Not Available"
    except AttributeError:
        return "Price Not Available"

# %%
def get_rating(soup):
    try:
        return soup.find("span", attrs={"class": "a-icon-alt"}).text.strip()
    except AttributeError:
        return "No Rating Found"

# %%
def get_review_count(soup):
    try:
        return soup.find("span", attrs={"id": "acrCustomerReviewText"}).text.strip()
    except AttributeError:
        return "No Reviews Found"

# %%
def get_availability(soup):
    try:
        availability = soup.find("div", attrs={"id": "availability"}).find("span").text.strip()
        if "in stock" in availability.lower():
            return "In Stock"
        elif "out of stock" in availability.lower():
            return "Out of Stock"
        else:
            return "Availability Unknown"
    except AttributeError:
        return "Availability Unknown"

# %%
def get_product_description(soup):
    try:
        description = soup.find("div", attrs={"id": "productDescription"})
        if description:
            return description.get_text(separator=" ", strip=True)
        return "No Description Available"
    except AttributeError:
        return "No Description Available"

# %%
def get_image_url(soup):
    try:
        image_tag = soup.find("img", attrs={"id": "landingImage"})
        return image_tag['src'] if image_tag else "No Image Available"
    except AttributeError:
        return "No Image Available"

# %%
def get_brand(soup):
    try:
        brand = soup.find("a", attrs={"id": "bylineInfo"})
        return brand.text.strip() if brand else "No Brand Available"
    except AttributeError:
        return "No Brand Available"

# %%
# Main Script
if __name__ == "__main__":
    # Prompt for user input
    search_url = input("Enter the Amazon search URL : ")

    # Extract product links from the search URL
    links = get_product_links(search_url)

    # Collect Data
    data = {"title": [], "price": [], "rating": [], "reviews": [], "availability": [],
            "product_details": [], "image_url": [], "brand": []}

    for link in links:
        details = get_product_details(link)
        for key in data.keys():
            data[key].append(details[key])

    # Create DataFrame and Save to CSV
    amazon_df = pd.DataFrame.from_dict(data)
    amazon_df.replace('', np.nan, inplace=True)
    amazon_df.dropna(subset=['title'], inplace=True)
    amazon_df.to_csv("amazon_data.csv", index=False)

    print("Data scraping complete. The results have been saved to 'amazon_data.csv'.")
# Out:
# Enter the Amazon search URL : https://www.amazon.com/s?k=playstation+4
# Data scraping complete. The results have been saved to 'amazon_data.csv'.

# %%
amazon_df
# Out:
#                                                 title price  \
# 0          Sony PlayStation 4 500GB Console (Renewed)  173.
# 1   Sony PlayStation 4 500GB Premium Bundle (Renewed)  224.
# 2              Sony Playstation PS4 1TB Black Console  368.
# 3   Sony PlayStation 4 Slim Limited Edition 1TB Ga...  216.
# 4   Playstation SONY 4, 500GB Slim System [CUH-221...  224.
# 5                      PlayStation 4 Slim 1TB Console  369.
# 6   Sony Playstation 4 500GB white, 9466314 (Renewed)  184.
# 7   Playstation Sony 4, 500GB Slim System [CUH-221...  324.
# 8   Sony PlayStation 4 Pro w/ Accessories, 1TB HDD...  224.
# 9   Sony PlayStation 4 Pro 1TB Premium Bundle (Ren...  274.
# 10                     PlayStation 4 Slim 1TB Console  185.
# 11  PlayStation®4 Console – Call of Duty® Modern W...  379.
# 12  Sony PlayStation 4 Slim 1TB Premium Bundle (Re...  274.
# 13   Sony PlayStation 4 Console 1TB - Black (Renewed)  233.
# 14         Sony PlayStation 4 Console, Renewed, Black  209.
# 15  PlayStation 4 500GB Console [Old Model][Discon...  104.
# 16       Sony PlayStation 2 Console - Black (Renewed)  150.
# 17  Sony PlayStation 4 Pro w/ Accessories, 1TB HDD...  224.
# 18    Sony Original Playstation One Console (Renewed)   89.
# 19  Sony Playstation 3 160GB CECH-3001A, Console O...  147.
# 20  PlayStation 3 Slim Console 120GB (Old Model) (...  134.
# 21  Controller for PS4, Wireless Controller Blue f...   25.
# 22  Controller for PS4, Wireless Controller Blue f...   25.
#
#                 rating           reviews          availability  \
# 0   4.4 out of 5 stars     2,812 ratings              In Stock
# 1   4.5 out of 5 stars        26 ratings              In Stock
# 2   4.5 out of 5 stars     1,560 ratings              In Stock
# 3   4.5 out of 5 stars     1,497 ratings              In Stock
# 4   4.5 out of 5 stars       482 ratings              In Stock
# 5   4.5 out of 5 stars    15,737 ratings              In Stock
# 6   4.5 out of 5 stars        44 ratings              In Stock
# 7   4.5 out of 5 stars       372 ratings              In Stock
# 8   4.5 out of 5 stars     1,038 ratings              In Stock
# 9   4.5 out of 5 stars          1 rating  Availability Unknown
# 10  4.3 out of 5 stars       310 ratings              In Stock
# 11  4.5 out of 5 stars       118 ratings              In Stock
# 12  4.5 out of 5 stars  No Reviews Found              In Stock
# 13  4.5 out of 5 stars        11 ratings              In Stock
# 14  4.5 out of 5 stars       232 ratings              In Stock
# 15  4.5 out of 5 stars    13,607 ratings              In Stock
# 16  4.4 out of 5 stars     1,521 ratings  Availability Unknown
# 17  4.5 out of 5 stars     1,038 ratings              In Stock
# 18  4.4 out of 5 stars       439 ratings  Availability Unknown
# 19  4.6 out of 5 stars       379 ratings              In Stock
# 20  4.6 out of 5 stars       281 ratings              In Stock
# 21  4.3 out of 5 stars     1,211 ratings              In Stock
# 22  4.3 out of 5 stars     1,211 ratings              In Stock
#
#                                       product_details  \
# 0   This pre-owned or refurbished product has been...
# 1   This pre-owned or refurbished product has been...
# 2                            No Description Available
# 3   Edition:Slim 1TB The all new lighter and slimm...
# 4   The PS4 system focuses on the gamer, ensuring ...
# 5   The all new lighter and slimmer PlayStation4 s...
# 6   This pre-owned or refurbished product has been...
# 7   The all new lighter and slimmer PlayStation4 s...
# 8   Enhanced games - PS4 Pro games burst into life...
# 9   The PlayStation 4 Pro 1TB is a powerful gaming...
# 10                     PlayStation 4 Slim 1TB Console
# 11  What's in the Box Bundle includes: PlayStation...
# 12  The PlayStation 4 Slim 1TB Premium Bundle offe...
# 13  The PlayStation 4 console will unlock your gam...
# 14  PlayStation 4 Console manufacturer refurbished...
# 15                                                NaN
# 16  For sale is a fully functional PS2 console. Yo...
# 17  Enhanced games - PS4 Pro games burst into life...
# 18  Included is the AV cable, power cable, one con...
# 19  This pre-owned or refurbished product has been...
# 20  Free membership and access to all the events, ...
# 21                           No Description Available
# 22                           No Description Available
#
#                                             image_url  \
# 0   https://m.media-amazon.com/images/I/31oeRyFo94...
# 1   https://m.media-amazon.com/images/I/31jy-7fYIz...
# 2   https://m.media-amazon.com/images/I/417m+qsw4J...
# 3   https://m.media-amazon.com/images/I/31NHoF8tL6...
# 4   https://m.media-amazon.com/images/I/51tbWVPtck...
# 5   https://m.media-amazon.com/images/I/3142A+G-ej...
# 6   https://m.media-amazon.com/images/I/31PtzA5+mz...
# 7   https://m.media-amazon.com/images/I/31aelHds6g...
# 8   https://m.media-amazon.com/images/I/31KK-7Ru8h...
# 9   https://m.media-amazon.com/images/I/31Mi8SvydJ...
# 10  https://m.media-amazon.com/images/I/31CFdT96HB...
# 11  https://m.media-amazon.com/images/I/51DAnyM2dH...
# 12  https://m.media-amazon.com/images/I/31bhmA++-q...
# 13  https://m.media-amazon.com/images/I/318U30NVk6...
# 14  https://m.media-amazon.com/images/I/41zUUPssyn...
# 15  https://m.media-amazon.com/images/I/31y9itjuio...
# 16  https://m.media-amazon.com/images/I/419nJrbB0j...
# 17  https://m.media-amazon.com/images/I/31KK-7Ru8h...
# 18  https://m.media-amazon.com/images/I/318gwdqQ68...
# 19  https://m.media-amazon.com/images/I/31Iz73VaMM...
# 20  https://m.media-amazon.com/images/I/514hyDUqKT...
# 21  https://m.media-amazon.com/images/I/61SzVSIXCY...
# 22  https://m.media-amazon.com/images/I/61SzVSIXCY...
#
#                              brand
# 0   Visit the Amazon Renewed Store
# 1            Brand: Amazon Renewed
# 2             Visit the Sony Store
# 3   Visit the Amazon Renewed Store
# 4   Visit the Amazon Renewed Store
# 5      Visit the PlayStation Store
# 6   Visit the Amazon Renewed Store
# 7      Visit the PlayStation Store
# 8   Visit the Amazon Renewed Store
# 9            Brand: Amazon Renewed
# 10            Visit the Sony Store
# 11     Visit the PlayStation Store
# 12           Brand: Amazon Renewed
# 13  Visit the Amazon Renewed Store
# 14  Visit the Amazon Renewed Store
# 15     Visit the PlayStation Store
# 16           Brand: Amazon Renewed
# 17  Visit the Amazon Renewed Store
# 18  Visit the Amazon Renewed Store
# 19  Visit the Amazon Renewed Store
# 20  Visit the Amazon Renewed Store
# 21        Visit the CHENGDAO Store
# 22        Visit the CHENGDAO Store
